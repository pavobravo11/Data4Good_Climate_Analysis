# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:\\\\Docs\\\\mTemp\\\\Data_for_Good\\\\AirQualityIndex.csv")

# %%
import datetime
df['Date'] = [datetime.datetime.strptime(d, "%Y-%m-%d").date() for d in df['Date']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Average Daily Value  119 non-null    float64
#  1   Date                 119 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 2.0+ KB

# %%
traffic_df = pd.read_csv("E:\\\\Docs\\\\mTemp\\\\Data_for_Good\\\\AveDailyTafficCalgaryDowntown.csv")

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            10 non-null     int64
#  1   Sum of Ave. Traffic by Million  10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 288.0 bytes

# %%
# %matplotlib inline
figure, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1, figsize = (17,8))
ax1.plot(df['Date'], df['Average Daily Value'])
ax1.set_title("Quality Index")
ax2.plot(traffic_df['Year'], traffic_df['Sum of Ave. Traffic by Million'])
ax2.set_title("Traffic Volume")
plt.plot()
# Out:
# []
